# %% [markdown]
# # Australia's Weather Data Analysics

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Sakib\Desktop\Python_data_analytics\AUS_WEATHER\Weather Test Data.csv")

# %%
data
# Out:
#          row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0          Row0   Albury     12.9     25.7       0.0           46.0
# 1          Row1   Albury      9.2     28.0       0.0           24.0
# 2          Row2   Albury     14.3     25.0       0.0           50.0
# 3          Row3   Albury      9.7     31.9       0.0           80.0
# 4          Row4   Albury     15.9     18.6      15.6           61.0
# ...         ...      ...      ...      ...       ...            ...
# 42672  Row43633    Uluru      2.4     19.1       0.0           33.0
# 42673  Row43634    Uluru      2.3     21.4       0.0           22.0
# 42674  Row43635    Uluru      2.6     22.5       0.0           19.0
# 42675  Row43636    Uluru      7.4     20.6       0.0           35.0
# 42676  Row43637    Uluru      7.8     27.0       0.0           28.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0              W        WSW          19.0          26.0         38.0
# ...

# %%
data.head()
# Out:
#   row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0   Albury     12.9     25.7       0.0           46.0          W
# 1   Row1   Albury      9.2     28.0       0.0           24.0         SE
# 2   Row2   Albury     14.3     25.0       0.0           50.0         SW
# 3   Row3   Albury      9.7     31.9       0.0           80.0         SE
# 4   Row4   Albury     15.9     18.6      15.6           61.0        NNW
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
# 2          W          20.0          24.0         49.0         19.0
# 3         NW           7.0          28.0         42.0          9.0
# 4        NNW          28.0          28.0         76.0         93.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# ...

# %%
data.shape
# Out:
# (42677, 17)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=42677, step=1)

# %%
data.columns
# Out:
# Index(['row ID', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am',
#        'Temp3pm', 'RainToday'],
#       dtype='object')

# %%
data.dtypes
# Out:
# row ID            object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# dtype: object

# %%
data['MinTemp'].unique()
# Out:
# array([12.9,  9.2, 14.3,  9.7, 15.9, 11.5, 16.2, 12. , 11.3, 13.7, 16.9,
#        17.4, 10.5, 13.9, 19.3, 24.4, 18.5, 20.4, 22.3, 21.5, 18.4, 16.1,
#        13.3, 12.5,  8.9, 16. , 13.8, 15.5, 10. , 10.8, 10.7, 13.5,  7. ,
#         6.2,  1.8,  3.2,  6.9, 12.4,  3.7,  6.7,  9.3,  1.7,  8. , 10.6,
#         4.7,  3.4, -1.5, -1.7, -0.4,  4.8,  8.1,  2.9, -0.6,  3.6,  6.6,
#         4.2,  3.3, -0.8,  1.9,  2.7,  0.6,  7.2,  5.1,  6.1,  8.3,  6.5,
#         5.3,  6.8,  4.5,  5.5,  4. , 11.7,  4.6,  4.1,  7.4,  5.9, 18.7,
#        11.4, 18.3, 13.2, 13.4,  9. , 11.8, 13.1, 17.8, 18.6, 20.6, 16.8,
#        15.1, 21.7, 23.5, 19.5, 20.3, 17.6,  nan, 20.2, 18.2, 11.2, 18.8,
#        15.7, 12.6, 14.2,  5.6, 15.4,  3. ,  3.1,  1.4,  2.1, 10.2,  5.7,
#         9.4, -1. , -0.3,  1.5,  3.5,  1. ,  0. ,  5. , -0.5,  2.5, -1.2,
#         7.5,  5.4,  1.3,  6.4,  2.3,  9.8,  2.4,  8.6, -0.1, 10.1,  7.3,
#         8.8,  7.1, 11.6, 17.5, 21.1, 14.8, 18.9, 16.7, 21.3, 10.3,  9.1,
# ...

# %%
data['MaxTemp'].nunique()
# Out:
# 474

# %%
data.nunique()
# Out:
# row ID           42677
# Location            49
# MinTemp            370
# MaxTemp            474
# Rainfall           460
# WindGustSpeed       62
# WindDir9am          16
# WindDir3pm          16
# WindSpeed9am        38
# WindSpeed3pm        37
# Humidity9am        100
# Humidity3pm        100
# Pressure9am        500
# Pressure3pm        489
# Temp9am            413
# Temp3pm            472
# RainToday            2
# dtype: int64

# %%
data.count()
# Out:
# row ID           42677
# Location         42677
# MinTemp          42483
# MaxTemp          42585
# Rainfall         42250
# WindGustSpeed    39887
# WindDir9am       39670
# WindDir3pm       41547
# WindSpeed9am     42264
# WindSpeed3pm     41882
# Humidity9am      42136
# Humidity3pm      41573
# Pressure9am      38411
# Pressure3pm      38432
# Temp9am          42387
# Temp3pm          41855
# RainToday        42250
# dtype: int64

# %%
data['MinTemp'].value_counts()
# Out:
#  10.2    272
#  9.6     271
#  13.3    261
#  10.4    261
#  8.5     259
#         ...
# -6.6       1
# -5.8       1
# -8.2       1
# -7.6       1
#  31.0      1
# Name: MinTemp, Length: 370, dtype: int64

# %%
data['MaxTemp'].value_counts()
# Out:
#  20.8    274
#  20.0    256
#  19.3    255
#  19.9    250
#  19.0    250
#         ...
#  0.8       1
# -0.4       1
# -1.7       1
#  0.9       1
#  46.3      1
# Name: MaxTemp, Length: 474, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42677 entries, 0 to 42676
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row ID         42677 non-null  object
#  1   Location       42677 non-null  object
#  2   MinTemp        42483 non-null  float64
#  3   MaxTemp        42585 non-null  float64
#  4   Rainfall       42250 non-null  float64
#  5   WindGustSpeed  39887 non-null  float64
#  6   WindDir9am     39670 non-null  object
#  7   WindDir3pm     41547 non-null  object
#  8   WindSpeed9am   42264 non-null  float64
#  9   WindSpeed3pm   41882 non-null  float64
#  10  Humidity9am    42136 non-null  float64
#  11  Humidity3pm    41573 non-null  float64
#  12  Pressure9am    38411 non-null  float64
#  13  Pressure3pm    38432 non-null  float64
#  14  Temp9am        42387 non-null  float64
#  15  Temp3pm        41855 non-null  float64
#  16  RainToday      42250 non-null  object
# ...

# %% [markdown]
# # Finding all the unique 'Wind Speed' values in the data
# WindSpeed9am

# %%
data.head(5)
# Out:
#   row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0   Albury     12.9     25.7       0.0           46.0          W
# 1   Row1   Albury      9.2     28.0       0.0           24.0         SE
# 2   Row2   Albury     14.3     25.0       0.0           50.0         SW
# 3   Row3   Albury      9.7     31.9       0.0           80.0         SE
# 4   Row4   Albury     15.9     18.6      15.6           61.0        NNW
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
# 2          W          20.0          24.0         49.0         19.0
# 3         NW           7.0          28.0         42.0          9.0
# 4        NNW          28.0          28.0         76.0         93.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# ...

# %%
data.nunique()
# Out:
# row ID           42677
# Location            49
# MinTemp            370
# MaxTemp            474
# Rainfall           460
# WindGustSpeed       62
# WindDir9am          16
# WindDir3pm          16
# WindSpeed9am        38
# WindSpeed3pm        37
# Humidity9am        100
# Humidity3pm        100
# Pressure9am        500
# Pressure3pm        489
# Temp9am            413
# Temp3pm            472
# RainToday            2
# dtype: int64

# %%
data['WindSpeed9am'].nunique()
# Out:
# 38

# %%
data['WindSpeed9am'].unique()
# Out:
# array([19., 11., 20.,  7., 28.,  9., 17.,  6.,  4., 13.,  2., 15., 26.,
#         0., 22., 37., 35., 24., nan, 31., 30., 48., 33., 41., 43., 39.,
#        56., 46., 74., 44., 50., 52., 65., 57., 61., 59., 54., 67., 63.])

# %% [markdown]
# #  Finding all the unique 'Wind Speed' values in the data
# WindSpeed3pm

# %%
data['WindSpeed3pm'].nunique()
# Out:
# 37

# %%
data['WindSpeed3pm'].unique()
# Out:
# array([26.,  9., 24., 28., 13., 17., 31., 11., 15., 48., 19., nan, 33.,
#         4.,  7., 20.,  6., 22.,  0., 30., 37., 46., 35.,  2., 41., 39.,
#        43., 56., 44., 61., 54., 50., 52., 83., 57., 59., 69., 63.])

# %% [markdown]
# # Finding the number of times when it 'Rain'

# %%
#value_counts()
data.RainToday.value_counts()
# Out:
# No     32851
# Yes     9399
# Name: RainToday, dtype: int64

# %%
#Filtering
data.head(2)
data[data.RainToday == 'Yes'] # Showing all the RainToday Yes
# Out:
#          row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 4          Row4   Albury     15.9     18.6      15.6           61.0
# 30        Row31   Albury     10.0     19.7      11.6           39.0
# 34        Row35   Albury     10.7     21.4      12.6           43.0
# 35        Row36   Albury     13.5     24.2       6.2           20.0
# 42        Row43   Albury     12.4     16.4       1.8           52.0
# ...         ...      ...      ...      ...       ...            ...
# 42611  Row43571    Uluru     19.4     33.3       6.0           37.0
# 42617  Row43577    Uluru     22.9     29.9      21.8           35.0
# 42626  Row43586    Uluru     23.1     34.5       6.4           50.0
# 42627  Row43587    Uluru     21.8     25.4      17.2           37.0
# 42653  Row43614    Uluru     17.7     26.9      12.6           35.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 4            NNW        NNW          28.0          28.0         76.0
# ...

# %%
#groupby()
data.groupby('RainToday').get_group('No') # Showing all the RainToday No
# Out:
#          row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0          Row0   Albury     12.9     25.7       0.0           46.0
# 1          Row1   Albury      9.2     28.0       0.0           24.0
# 2          Row2   Albury     14.3     25.0       0.0           50.0
# 3          Row3   Albury      9.7     31.9       0.0           80.0
# 5          Row6   Albury     11.5     29.3       0.0           24.0
# ...         ...      ...      ...      ...       ...            ...
# 42672  Row43633    Uluru      2.4     19.1       0.0           33.0
# 42673  Row43634    Uluru      2.3     21.4       0.0           22.0
# 42674  Row43635    Uluru      2.6     22.5       0.0           19.0
# 42675  Row43636    Uluru      7.4     20.6       0.0           35.0
# 42676  Row43637    Uluru      7.8     27.0       0.0           28.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0              W        WSW          19.0          26.0         38.0
# ...

# %% [markdown]
# # Find the number of times when the Wind Speed was exactly 6 km/h WindSpeed9am

# %%
data.head(2)
# Out:
#   row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0   Albury     12.9     25.7       0.0           46.0          W
# 1   Row1   Albury      9.2     28.0       0.0           24.0         SE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# 1       1017.6       1012.8     18.1     26.5        No

# %%
data[data['WindSpeed9am'] == 6]
# Out:
#          row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 9         Row10   Albury     12.9     35.8       0.0           41.0
# 27        Row28   Albury     16.0     34.5       0.0           44.0
# 32        Row33   Albury     10.8     31.9       0.0           48.0
# 40        Row41   Albury      3.2     18.4       0.0           20.0
# 48        Row49   Albury     10.6     14.3       4.8           13.0
# ...         ...      ...      ...      ...       ...            ...
# 42470  Row43430    Uluru      8.5     31.7       0.0           43.0
# 42543  Row43503    Uluru     18.7     30.5       0.2           31.0
# 42557  Row43517    Uluru      6.1     17.7       0.0           24.0
# 42609  Row43569    Uluru     23.6     31.9       0.4           48.0
# 42664  Row43625    Uluru      6.4     29.6       0.0           50.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 9            ENE         NW           6.0          26.0         41.0
# ...

# %% [markdown]
# # Find the number of times when the Wind Speed was exactly 6 km/h WindSpeed3pm

# %%
data[data['WindSpeed3pm'] == 6]
# Out:
#          row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 35        Row36   Albury     13.5     24.2       6.2           20.0
# 63        Row64   Albury     -0.8     12.9       4.2           24.0
# 66        Row67   Albury      0.6     15.6       0.0           15.0
# 112      Row113   Albury     20.3     33.9       0.0           37.0
# 129      Row131   Albury      6.1     23.5       0.0           17.0
# ...         ...      ...      ...      ...       ...            ...
# 42416  Row43375    Uluru     23.4     42.3       0.0           37.0
# 42422  Row43381    Uluru     15.9     35.8       0.0           43.0
# 42431  Row43390    Uluru      4.8     25.3       0.0           28.0
# 42475  Row43435    Uluru     12.6     30.8       0.0           48.0
# 42605  Row43565    Uluru     24.5     33.9       0.0           76.0
#
#       WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 35           NaN         SE           0.0           6.0         88.0
# ...

# %% [markdown]
# # Finding the Null Values in the data

# %%
data.isnull()
# Out:
#        row ID  Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 0       False     False    False    False     False          False
# 1       False     False    False    False     False          False
# 2       False     False    False    False     False          False
# 3       False     False    False    False     False          False
# 4       False     False    False    False     False          False
# ...       ...       ...      ...      ...       ...            ...
# 42672   False     False    False    False     False          False
# 42673   False     False    False    False     False          False
# 42674   False     False    False    False     False          False
# 42675   False     False    False    False     False          False
# 42676   False     False    False    False     False          False
#
#        WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0           False       False         False         False        False
# ...

# %%
data.isnull().sum()
# Out:
# row ID              0
# Location            0
# MinTemp           194
# MaxTemp            92
# Rainfall          427
# WindGustSpeed    2790
# WindDir9am       3007
# WindDir3pm       1130
# WindSpeed9am      413
# WindSpeed3pm      795
# Humidity9am       541
# Humidity3pm      1104
# Pressure9am      4266
# Pressure3pm      4245
# Temp9am           290
# Temp3pm           822
# RainToday         427
# dtype: int64

# %%
data.notnull().sum()
# Out:
# row ID           42677
# Location         42677
# MinTemp          42483
# MaxTemp          42585
# Rainfall         42250
# WindGustSpeed    39887
# WindDir9am       39670
# WindDir3pm       41547
# WindSpeed9am     42264
# WindSpeed3pm     41882
# Humidity9am      42136
# Humidity3pm      41573
# Pressure9am      38411
# Pressure3pm      38432
# Temp9am          42387
# Temp3pm          41855
# RainToday        42250
# dtype: int64

# %% [markdown]
# # Renaming the column name 'Location' to "Suburb"

# %%
data.head(2)
# Out:
#   row ID Location  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0   Albury     12.9     25.7       0.0           46.0          W
# 1   Row1   Albury      9.2     28.0       0.0           24.0         SE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# 1       1017.6       1012.8     18.1     26.5        No

# %%
data.rename(columns = {'Location' : 'Suburb'}, inplace = True)

# %%
data.head()
# Out:
#   row ID  Suburb  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0  Albury     12.9     25.7       0.0           46.0          W
# 1   Row1  Albury      9.2     28.0       0.0           24.0         SE
# 2   Row2  Albury     14.3     25.0       0.0           50.0         SW
# 3   Row3  Albury      9.7     31.9       0.0           80.0         SE
# 4   Row4  Albury     15.9     18.6      15.6           61.0        NNW
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
# 2          W          20.0          24.0         49.0         19.0
# 3         NW           7.0          28.0         42.0          9.0
# 4        NNW          28.0          28.0         76.0         93.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# ...

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
sns.displot(data['MaxTemp'])

# %%
sns.pairplot(data[['MaxTemp', 'MinTemp']])

# %% [markdown]
# # Finding the mean "Pressure9am"

# %%
data.Pressure9am.mean()
# Out:
# 1017.581591210851

# %% [markdown]
# # Finding the mean "Pressure3pm"

# %%
data.Pressure3pm.mean()
# Out:
# 1015.1927918661534

# %%
data.head(2)
# Out:
#   row ID  Suburb  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0   Row0  Albury     12.9     25.7       0.0           46.0          W
# 1   Row1  Albury      9.2     28.0       0.0           24.0         SE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WSW          19.0          26.0         38.0         30.0
# 1          E          11.0           9.0         45.0         16.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.6       1008.7     21.0     23.2        No
# 1       1017.6       1012.8     18.1     26.5        No

# %% [markdown]
# # Finding the Standard Deviation of Humidity9am

# %%
data.Humidity9am.std()
# Out:
# 18.996115195779854

# %% [markdown]
# # Finding the Standard Deviation of Humidity3pm

# %%
data.Humidity3pm.std()
# Out:
# 20.84452548344115

# %%
sns.displot(data['Humidity9am'])

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
sns.displot(data['Humidity3pm'])

# %% [markdown]
# # Finding the Variance of 'WindSpeed9am'

# %%
data.WindSpeed9am.var()
# Out:
# 78.72027713135276

# %% [markdown]
# # Findind the Variance of 'WindSpeed3pm'

# %%
data.WindSpeed3pm.var()
# Out:
# 77.5617667642119

# %% [markdown]
# # Finding all instances when WindDir9am	is "NNW"

# %%
data[data['WindDir9am'] == 'NNW']
# Out:
#          row ID  Suburb  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 4          Row4  Albury     15.9     18.6      15.6           61.0        NNW
# 67        Row68  Albury      8.9     17.1       1.2           63.0        NNW
# 76        Row77  Albury     11.5     20.2       8.4           50.0        NNW
# 144      Row146  Albury     -1.0     13.1       0.0           11.0        NNW
# 167      Row169  Albury      5.4     11.8       9.6           50.0        NNW
# ...         ...     ...      ...      ...       ...            ...        ...
# 42486  Row43446   Uluru     18.2     38.6       0.0           46.0        NNW
# 42491  Row43451   Uluru     23.4     32.5       0.4           56.0        NNW
# 42500  Row43460   Uluru     23.1     41.9       0.0           69.0        NNW
# 42510  Row43470   Uluru     25.7     38.0       0.0           57.0        NNW
# 42598  Row43558   Uluru      6.5     35.2       0.0           50.0        NNW
#
# ...

# %% [markdown]
# # Finding all instances when WindDir3pm	is "WSW"

# %%
data[data['WindDir3pm'] == 'WSW']
# Out:
#          row ID  Suburb  MinTemp  MaxTemp  Rainfall  WindGustSpeed WindDir9am  \
# 0          Row0  Albury     12.9     25.7       0.0           46.0          W
# 6          Row7  Albury     16.2     33.9       0.0           35.0         SE
# 15        Row16  Albury     19.3     38.1       0.8           61.0         NE
# 22        Row23  Albury     18.4     31.2       0.4           37.0         SW
# 26        Row27  Albury      8.9     31.9       0.0           43.0        NaN
# ...         ...     ...      ...      ...       ...            ...        ...
# 42446  Row43405   Uluru     10.0     25.6       0.0           26.0        ESE
# 42486  Row43446   Uluru     18.2     38.6       0.0           46.0        NNW
# 42551  Row43511   Uluru     12.7     28.7       0.0           31.0         NW
# 42602  Row43562   Uluru     17.5     35.5       0.0           46.0        ESE
# 42618  Row43578   Uluru     23.2     38.0       0.0           33.0          S
#
# ...

# %% [markdown]
# # Findind all instances when 'WindSpeed9am' is above '15' and 'Temp9am' is '25'

# %%
data[(data['WindSpeed9am'] > 15) & (data['Temp9am'] == 25)]
# Out:
#          row ID         Suburb  MinTemp  MaxTemp  Rainfall  WindGustSpeed  \
# 1707    Row1738  BadgerysCreek     17.8     34.7       0.0           41.0
# 1778    Row1809          Cobar     23.0     38.9       0.0           65.0
# 3400    Row3456   CoffsHarbour     21.4     30.7       0.0           50.0
# 3642    Row3698          Moree     20.6     35.4       0.0           48.0
# 3754    Row3810          Moree     19.5     31.3       0.0           50.0
# 3908    Row3967          Moree     17.6     31.9       0.0           43.0
# 4154    Row4239          Moree     20.0     33.7       0.0           37.0
# 4240    Row4346          Moree     13.4     33.1       0.0           56.0
# 4320    Row4427          Moree     18.6     34.8       0.0           46.0
# 5324    Row5448      NorahHead     13.8     32.0       0.0           43.0
# 5985    Row6128      NorahHead     22.3     27.3       0.8           39.0
# 6417    Row6560  NorfolkIsland     23.3     26.9       9.4           43.0
# ...

# %% [markdown]
# # Finding the mean value of each column against each 'RainToday'

# %%
data.groupby('RainToday').mean()
# Out:
# C:\Users\Sakib\AppData\Local\Temp\ipykernel_17212\3642858445.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('RainToday').mean()
#              MinTemp    MaxTemp   Rainfall  WindGustSpeed  WindSpeed9am  \
# RainToday
# No         12.032163  24.138466   0.073535      38.821940     13.474327
# Yes        12.834208  20.170574  10.274519      44.077585     15.744720
#
#            WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# RainToday
# No            18.230719     65.17162    47.336933  1018.319947  1015.610536
# Yes           19.885495     81.45487    66.367523  1014.996605  1013.732128
#
#              Temp9am    Temp3pm
# RainToday
# No         17.382283  22.591742
# Yes        15.797371  18.619592
